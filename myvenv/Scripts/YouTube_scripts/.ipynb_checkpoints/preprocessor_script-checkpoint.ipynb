# %%
import numpy as np
import pandas as pd
import os

# %%
data_source = pd.read_excel(r'Global_YouTube_Statistics.xlsx')
data_source
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  228000000000
# 1       2              YouTube Movies    170000000             0
# 2       3                     MrBeast    166000000   28368841870
# 3       4  Cocomelon - Nursery Rhymes    162000000  164000000000
# 4       5                   SET India    159000000  148000000000
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000    9029609749
# 991   992    Free Fire India Official     12300000    1674409945
# 992   993                       Panda     12300000    2214684303
# 993   994                 RobTopGames     12300000     374123483
# 994   995                Make Joke Of     12300000    2129773714
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# 1    Film & Animation               youtubemovies        1   United States
# 2       Entertainment                     MrBeast      741   United States
# 3           Education  Cocomelon - Nursery Rhymes      966   United States
# 4               Shows                   SET India   116536           India
# ..                ...                         ...      ...             ...
# 990            Sports               Natan por Aï¿     1200          Brazil
# 991    People & Blogs    Free Fire India Official     1500           India
# 992               NaN                 HybridPanda     2452  United Kingdom
# 993            Gaming                 RobTopGames       39          Sweden
# 994            Comedy                Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0             IN          Music  ...                     2000000.0
# 1             US          Games  ...                           NaN
# 2             US  Entertainment  ...                     8000000.0
# 3             US      Education  ...                     1000000.0
# 4             IN  Entertainment  ...                     1000000.0
# ..           ...            ...  ...                           ...
# 990           BR  Entertainment  ...                      700000.0
# 991           IN          Games  ...                      300000.0
# 992           GB          Games  ...                        1000.0
# 993           SE          Games  ...                      100000.0
# 994           IN         Comedy  ...                      100000.0
#
#      created_year  created_month  created_date  \
# 0          2006.0            Mar          13.0
# 1          2006.0            Mar           5.0
# 2          2012.0            Feb          20.0
# 3          2006.0            Sep           1.0
# 4          2006.0            Sep          20.0
# ..            ...            ...           ...
# 990        2017.0            Feb          12.0
# 991        2018.0            Sep          14.0
# 992        2006.0            Sep          11.0
# 993        2012.0            May           9.0
# 994        2017.0            Aug           1.0
#
#      Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# 0                                       28.1  1.366418e+09               5.36
# 1                                       88.2  3.282395e+08              14.70
# 2                                       88.2  3.282395e+08              14.70
# 3                                       88.2  3.282395e+08              14.70
# 4                                       28.1  1.366418e+09               5.36
# ..                                       ...           ...                ...
# 990                                     51.3  2.125594e+08              12.08
# 991                                     28.1  1.366418e+09               5.36
# 992                                     60.0  6.683440e+07               3.85
# 993                                     67.0  1.028545e+07               6.48
# 994                                     28.1  1.366418e+09               5.36
#
#      Urban_population   Latitude  Longitude
# 0         471031528.0  20.593684  78.962880
# 1         270663028.0  37.090240 -95.712891
# 2         270663028.0  37.090240 -95.712891
# 3         270663028.0  37.090240 -95.712891
# 4         471031528.0  20.593684  78.962880
# ..                ...        ...        ...
# 990       183241641.0 -14.235004 -51.925280
# 991       471031528.0  20.593684  78.962880
# 992        55908316.0  55.378051  -3.435973
# 993         9021165.0  60.128161  18.643501
# 994       471031528.0  20.593684  78.962880
#
# [995 rows x 28 columns]

# %%
print(data_source.columns)
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
for index, column in enumerate(data_source.columns):
    print(f"index: {index}, column_name: {column}")
# Out:
# index: 0, column_name: rank
# index: 1, column_name: Youtuber
# index: 2, column_name: subscribers
# index: 3, column_name: video views
# index: 4, column_name: category
# index: 5, column_name: Title
# index: 6, column_name: uploads
# index: 7, column_name: Country
# index: 8, column_name: Abbreviation
# index: 9, column_name: channel_type
# index: 10, column_name: video_views_rank
# index: 11, column_name: country_rank
# index: 12, column_name: channel_type_rank
# index: 13, column_name: video_views_for_the_last_30_days
# index: 14, column_name: lowest_monthly_earnings
# index: 15, column_name: highest_monthly_earnings
# index: 16, column_name: lowest_yearly_earnings
# index: 17, column_name: highest_yearly_earnings
# index: 18, column_name: subscribers_for_last_30_days
# index: 19, column_name: created_year
# index: 20, column_name: created_month
# index: 21, column_name: created_date
# index: 22, column_name: Gross tertiary education enrollment (%)
# index: 23, column_name: Population
# index: 24, column_name: Unemployment rate
# index: 25, column_name: Urban_population
# index: 26, column_name: Latitude
# index: 27, column_name: Longitude

# %%
columns_to_drop = ['Title',
                    'uploads',
                    'Abbreviation', 
                    'channel_type',
                    'video_views_rank', 
                    'country_rank', 
                    'channel_type_rank',
                    'video_views_for_the_last_30_days',
                    'lowest_monthly_earnings',
                    'highest_monthly_earnings',
                    'lowest_yearly_earnings',
                    'subscribers_for_last_30_days',
                    'created_year', 
                    'created_month',
                    'created_date',
                    'Gross tertiary education enrollment (%)',
                    'Population',
                    'Unemployment rate', 
                    'Urban_population',
                    'Latitude', 
                    'Longitude']
 
data_source.drop(columns=columns_to_drop, inplace = True)
print(data_source)
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  228000000000
# 1       2              YouTube Movies    170000000             0
# 2       3                     MrBeast    166000000   28368841870
# 3       4  Cocomelon - Nursery Rhymes    162000000  164000000000
# 4       5                   SET India    159000000  148000000000
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000    9029609749
# 991   992    Free Fire India Official     12300000    1674409945
# 992   993                       Panda     12300000    2214684303
# 993   994                 RobTopGames     12300000     374123483
# 994   995                Make Joke Of     12300000    2129773714
#
#              category         Country  highest_yearly_earnings
# 0               Music           India             1.084000e+08
# 1    Film & Animation   United States             5.800000e-01
# 2       Entertainment   United States             6.470000e+07
# 3           Education   United States             9.480000e+07
# 4               Shows           India             8.750000e+07
# ..                ...             ...                      ...
# 990            Sports          Brazil             2.650000e+07
# 991    People & Blogs           India             3.100000e+06
# 992               NaN  United Kingdom             3.200000e+03
# 993            Gaming          Sweden             1.858000e+05
# 994            Comedy           India             1.200000e+06
#
# [995 rows x 7 columns]

# %%
data_source['Youtuber'] = data_source['Youtuber'].astype(str) 
data_source['category'] = data_source['category'].astype(str)
data_source['Country'] = data_source['Country'].astype(str) 
data_source['rank'] = data_source['rank'].astype(int)
data_source['subscribers'] = data_source['subscribers'].astype(int)
data_source['highest_yearly_earnings'] = data_source['highest_yearly_earnings'].astype(int)

# %%
print(data_source)
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  228000000000
# 1       2              YouTube Movies    170000000             0
# 2       3                     MrBeast    166000000   28368841870
# 3       4  Cocomelon - Nursery Rhymes    162000000  164000000000
# 4       5                   SET India    159000000  148000000000
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000    9029609749
# 991   992    Free Fire India Official     12300000    1674409945
# 992   993                       Panda     12300000    2214684303
# 993   994                 RobTopGames     12300000     374123483
# 994   995                Make Joke Of     12300000    2129773714
#
#              category         Country  highest_yearly_earnings
# 0               Music           India                108400000
# 1    Film & Animation   United States                        0
# 2       Entertainment   United States                 64700000
# 3           Education   United States                 94800000
# 4               Shows           India                 87500000
# ..                ...             ...                      ...
# 990            Sports          Brazil                 26500000
# 991    People & Blogs           India                  3100000
# 992               nan  United Kingdom                     3200
# 993            Gaming          Sweden                   185800
# 994            Comedy           India                  1200000
#
# [995 rows x 7 columns]

# %%
data_source.style.hide(axis = 'index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_8d6a0">
#   <thead>
#     <tr>
#       <th id="T_8d6a0_level0_col0" class="col_heading level0 col0" >rank</th>
#       <th id="T_8d6a0_level0_col1" class="col_heading level0 col1" >Youtuber</th>
#       <th id="T_8d6a0_level0_col2" class="col_heading level0 col2" >subscribers</th>
#       <th id="T_8d6a0_level0_col3" class="col_heading level0 col3" >video views</th>
#       <th id="T_8d6a0_level0_col4" class="col_heading level0 col4" >category</th>
#       <th id="T_8d6a0_level0_col5" class="col_heading level0 col5" >Country</th>
#       <th id="T_8d6a0_level0_col6" class="col_heading level0 col6" >highest_yearly_earnings</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8d6a0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8d6a0_row0_col1" class="data row0 col1" >T-Series</td>
#       <td id="T_8d6a0_row0_col2" class="data row0 col2" >245000000</td>
#       <td id="T_8d6a0_row0_col3" class="data row0 col3" >228000000000</td>
#       <td id="T_8d6a0_row0_col4" class="data row0 col4" >Music</td>
#       <td id="T_8d6a0_row0_col5" class="data row0 col5" >India</td>
#       <td id="T_8d6a0_row0_col6" class="data row0 col6" >108400000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_8d6a0_row1_col1" class="data row1 col1" >YouTube Movies</td>
#       <td id="T_8d6a0_row1_col2" class="data row1 col2" >170000000</td>
#       <td id="T_8d6a0_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_8d6a0_row1_col4" class="data row1 col4" >Film & Animation</td>
#       <td id="T_8d6a0_row1_col5" class="data row1 col5" >United States</td>
#       <td id="T_8d6a0_row1_col6" class="data row1 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_8d6a0_row2_col1" class="data row2 col1" >MrBeast</td>
#       <td id="T_8d6a0_row2_col2" class="data row2 col2" >166000000</td>
#       <td id="T_8d6a0_row2_col3" class="data row2 col3" >28368841870</td>
#       <td id="T_8d6a0_row2_col4" class="data row2 col4" >Entertainment</td>
#       <td id="T_8d6a0_row2_col5" class="data row2 col5" >United States</td>
#       <td id="T_8d6a0_row2_col6" class="data row2 col6" >64700000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_8d6a0_row3_col1" class="data row3 col1" >Cocomelon - Nursery Rhymes</td>
#       <td id="T_8d6a0_row3_col2" class="data row3 col2" >162000000</td>
#       <td id="T_8d6a0_row3_col3" class="data row3 col3" >164000000000</td>
#       <td id="T_8d6a0_row3_col4" class="data row3 col4" >Education</td>
#       <td id="T_8d6a0_row3_col5" class="data row3 col5" >United States</td>
#       <td id="T_8d6a0_row3_col6" class="data row3 col6" >94800000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_8d6a0_row4_col1" class="data row4 col1" >SET India</td>
#       <td id="T_8d6a0_row4_col2" class="data row4 col2" >159000000</td>
#       <td id="T_8d6a0_row4_col3" class="data row4 col3" >148000000000</td>
#       <td id="T_8d6a0_row4_col4" class="data row4 col4" >Shows</td>
#       <td id="T_8d6a0_row4_col5" class="data row4 col5" >India</td>
#       <td id="T_8d6a0_row4_col6" class="data row4 col6" >87500000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_8d6a0_row5_col1" class="data row5 col1" >Music</td>
#       <td id="T_8d6a0_row5_col2" class="data row5 col2" >119000000</td>
#       <td id="T_8d6a0_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_8d6a0_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_8d6a0_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_8d6a0_row5_col6" class="data row5 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_8d6a0_row6_col1" class="data row6 col1" >ýýý Kids Diana Show</td>
#       <td id="T_8d6a0_row6_col2" class="data row6 col2" >112000000</td>
#       <td id="T_8d6a0_row6_col3" class="data row6 col3" >93247040539</td>
#       <td id="T_8d6a0_row6_col4" class="data row6 col4" >People & Blogs</td>
#       <td id="T_8d6a0_row6_col5" class="data row6 col5" >United States</td>
#       <td id="T_8d6a0_row6_col6" class="data row6 col6" >35100000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_8d6a0_row7_col1" class="data row7 col1" >PewDiePie</td>
#       <td id="T_8d6a0_row7_col2" class="data row7 col2" >111000000</td>
#       <td id="T_8d6a0_row7_col3" class="data row7 col3" >29058044447</td>
#       <td id="T_8d6a0_row7_col4" class="data row7 col4" >Gaming</td>
#       <td id="T_8d6a0_row7_col5" class="data row7 col5" >Japan</td>
#       <td id="T_8d6a0_row7_col6" class="data row7 col6" >1900000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_8d6a0_row8_col1" class="data row8 col1" >Like Nastya</td>
#       <td id="T_8d6a0_row8_col2" class="data row8 col2" >106000000</td>
#       <td id="T_8d6a0_row8_col3" class="data row8 col3" >90479060027</td>
#       <td id="T_8d6a0_row8_col4" class="data row8 col4" >People & Blogs</td>
#       <td id="T_8d6a0_row8_col5" class="data row8 col5" >Russia</td>
#       <td id="T_8d6a0_row8_col6" class="data row8 col6" >2300000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_8d6a0_row9_col1" class="data row9 col1" >Vlad and Niki</td>
#       <td id="T_8d6a0_row9_col2" class="data row9 col2" >98900000</td>
#       <td id="T_8d6a0_row9_col3" class="data row9 col3" >77180169894</td>
#       <td id="T_8d6a0_row9_col4" class="data row9 col4" >Entertainment</td>
#       <td id="T_8d6a0_row9_col5" class="data row9 col5" >United States</td>
#       <td id="T_8d6a0_row9_col6" class="data row9 col6" >27900000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_8d6a0_row10_col1" class="data row10 col1" >Zee Music Company</td>
#       <td id="T_8d6a0_row10_col2" class="data row10 col2" >96700000</td>
#       <td id="T_8d6a0_row10_col3" class="data row10 col3" >57856289381</td>
#       <td id="T_8d6a0_row10_col4" class="data row10 col4" >Music</td>
#       <td id="T_8d6a0_row10_col5" class="data row10 col5" >India</td>
#       <td id="T_8d6a0_row10_col6" class="data row10 col6" >38600000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_8d6a0_row11_col1" class="data row11 col1" >WWE</td>
#       <td id="T_8d6a0_row11_col2" class="data row11 col2" >96000000</td>
#       <td id="T_8d6a0_row11_col3" class="data row11 col3" >77428473662</td>
#       <td id="T_8d6a0_row11_col4" class="data row11 col4" >Sports</td>
#       <td id="T_8d6a0_row11_col5" class="data row11 col5" >United States</td>
#       <td id="T_8d6a0_row11_col6" class="data row11 col6" >34300000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_8d6a0_row12_col1" class="data row12 col1" >Gaming</td>
#       <td id="T_8d6a0_row12_col2" class="data row12 col2" >93600000</td>
#       <td id="T_8d6a0_row12_col3" class="data row12 col3" >0</td>
#       <td id="T_8d6a0_row12_col4" class="data row12 col4" >nan</td>
#       <td id="T_8d6a0_row12_col5" class="data row12 col5" >nan</td>
#       <td id="T_8d6a0_row12_col6" class="data row12 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_8d6a0_row13_col1" class="data row13 col1" >BLACKPINK</td>
#       <td id="T_8d6a0_row13_col2" class="data row13 col2" >89800000</td>
#       <td id="T_8d6a0_row13_col3" class="data row13 col3" >32144597566</td>
#       <td id="T_8d6a0_row13_col4" class="data row13 col4" >People & Blogs</td>
#       <td id="T_8d6a0_row13_col5" class="data row13 col5" >South Korea</td>
#       <td id="T_8d6a0_row13_col6" class="data row13 col6" >23900000</td>
#     </tr>
#     <tr>
#       <td id="T_8d6a0_row14_col0" class="
